# %% [markdown]
# #Installing keras ocr
# > Add blockquote

# %%
# !pip install -q keras-ocr
# !pip install --force-reinstall -v "tensorflow==2.15.1"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.2/912.2 kB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.2 MB/s eta 0:00:00
# Using pip 24.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# ...
#   Obtaining dependency information for tensorflow==2.15.1 from https://files.pythonhosted.org/packages/4f/42/433c0c64c5d3b8bee696cde2006d15f03f0504c2f746d49f38e32e52e239/tensorflow-2.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/a2/ad/e0d3c824784ff121c03cc031f944bc7e139a8f1870ffd2845cc2dd76f6c4/absl_py-2.1.0-py3-none-any.whl.metadata
# ...

# %% [markdown]
# #Importing libraries

# %%
import keras_ocr
import matplotlib.pyplot as plt

# %% [markdown]
# #Create pipeline i.e. download weights

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5

# %%
images = [
    keras_ocr.tools.read(img) for img in ['image1.png',
                                          'french_id_card.png'
    ]
]

# %% [markdown]
# #Get predictions

# %%
len(images)
# Out:
# 2

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[0])

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[1])

# %%
prediction_groups = pipeline.recognize(images)
# Out:
# ...
# 8/8 [==============================] - 70s 8s/step

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(10, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image,
                                    predictions=predictions,
                                    ax=ax)

# %% [markdown]
#  2 main problems are : 1) not doing great with numbers 2) not doing well showing names with spaces..it shows 2 distinct names not continous we sould customize our alphabet set which will include /?<> signature specific details
